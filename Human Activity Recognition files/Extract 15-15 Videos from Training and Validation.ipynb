# %% [markdown]
# # Make a training file with 50 categories and 15 videos of each class

# %%
import pandas as pd

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#                   label   youtube_id  time_start  time_end  split
# 0            testifying  ---QUuC4vJs          84        94  train
# 1      eating spaghetti  --3ouPhoy2A          20        30  train
# 2  dribbling basketball  --4-0ihtnBU          58        68  train
# 3        playing tennis  --56QUhyDQM         185       195  train
# 4           tap dancing  --6q_33gNew         132       142  train

# %%
final_train = pd.DataFrame()

# %%
sorted(train['label'].unique())
# Out:
# ['abseiling',
#  'air drumming',
#  'answering questions',
#  'applauding',
#  'applying cream',
#  'archery',
#  'arm wrestling',
#  'arranging flowers',
#  'assembling computer',
#  'auctioning',
#  'baby waking up',
#  'baking cookies',
#  'balloon blowing',
#  'bandaging',
#  'barbequing',
#  'bartending',
#  'beatboxing',
#  'bee keeping',
#  'belly dancing',
#  'bench pressing',
#  'bending back',
#  'bending metal',
#  'biking through snow',
#  'blasting sand',
#  'blowing glass',
#  'blowing leaves',
#  'blowing nose',
#  'blowing out candles',
#  'bobsledding',
#  'bookbinding',
#  'bouncing on trampoline',
#  'bowling',
#  'braiding hair',
#  'breading or breadcrumbing',
#  'breakdancing',
#  'brush painting',
#  'brushing hair',
#  'brushing teeth',
#  'building cabinet',
#  'building shed',
#  'bungee jumping',
#  'busking',
#  'canoeing or kayaking',
#  'capoeira',
#  'carrying baby',
#  'cartwheeling',
#  'carving pumpkin',
#  'catching fish',
# ...

# %%
len(sorted(train['label'].unique())) 
# walking up
# preparing salad
# inflating balloons
# pillow fight
# vacuuming floor
# Out:
# 400

# %%
train[train['label'] == "driving car" ].head(15)
# Out:
#             label   youtube_id  time_start  time_end  split
# 832   driving car  -KSm0RzIF-Y          30        40  train
# 932   driving car  -MVb_xJglWU           8        18  train
# 1029  driving car  -O3D5G8xrok         222       232  train
# 1233  driving car  -RdREpFcycY          50        60  train
# 1531  driving car  -Y7su5UxZkc           2        12  train
# 2559  driving car  -qzjWXpmWoI           3        13  train
# 2759  driving car  -vL0AJPil6E          47        57  train
# 3060  driving car  00P8qGvMgX4          87        97  train
# 3508  driving car  08us014ZLkU         105       115  train
# 3542  driving car  09hrf4tspQM           7        17  train
# 3678  driving car  0CVnwFc58Rg          97       107  train
# 4288  driving car  0OcMQ2Z49gw          45        55  train
# 4651  driving car  0VKc8TbBloE          24        34  train
# 4709  driving car  0WCttfSBVS8         117       127  train
# 4878  driving car  0Zca-a_Zn8o          45        55  train

# %%
final_train = final_train.append(train[train['label'] == "driving car" ].head(15))

# %%
final_train.shape
# Out:
# (675, 5)

# %%
final_train
# Out:
#                               label   youtube_id  time_start  time_end  split
# 1883                    paragliding  -efcBtG1KVo          51        61  train
# 1885                    paragliding  -eiAd94PTWw          35        45  train
# 1890                    paragliding  -enPIivwlsY        1821      1831  train
# 1999                    paragliding  -giSKLNiewY          41        51  train
# 2467                    paragliding  -p91kI1gx8s          19        29  train
# 2523                    paragliding  -qCYMzHkc2k           7        17  train
# 5149                    paragliding  0eE_3nvbClk          53        63  train
# 5368                    paragliding  0hrx0HwZxME           2        12  train
# 6017                    paragliding  0vCPUd1WQ4U          36        46  train
# 6617                    paragliding  15LSh_XPils         280       290  train
# 7117                    paragliding  1EXXo5VUaTg           1        11  train
# ...

# %%
final_train['label'].unique()
# Out:
# array(['paragliding', 'catching or throwing baseball', 'dancing macarena',
#        'laughing', 'eating cake', 'beatboxing', 'feeding birds',
#        'opening present', 'swinging on something', 'making pizza',
#        'kitesurfing', 'ice climbing', 'slacklining', 'chopping wood',
#        'cartwheeling', 'archery', 'welding', 'roller skating',
#        'playing flute', 'deadlifting', 'bouncing on trampoline',
#        'shoveling snow', 'playing keyboard', 'celebrating', 'high jump',
#        'capoeira', 'finger snapping', 'side kick', 'brushing hair',
#        'cooking sausages', 'throwing ball', 'hammer throw',
#        'dribbling basketball', 'stretching leg', 'breakdancing',
#        'snowmobiling', 'canoeing or kayaking', 'headbanging',
#        'exercising with an exercise ball', 'blowing out candles',
#        'watering plants', 'cheerleading', 'milking cow', 'snowboarding',
#        'driving car'], dtype=object)

# %%
len(final_train['label'].unique())
# Out:
# 45

# %%
final_train.to_csv("Trainig.csv")

# %% [markdown]
# # Make a Validation file with 50 categories and 15 videos of each class

# %%
val = pd.read_csv("validate.csv")
val.head()
# Out:
#                label   youtube_id  time_start  time_end     split
# 0      javelin throw  --07WQ2iBlw           1        11  validate
# 1   flipping pancake  --33Lscn6sk           4        14  validate
# 2  playing saxophone  --7VUM9MKg4         136       146  validate
# 3           slapping  --7goKgS4kc          15        25  validate
# 4         making tea  --7qK_w-g3Y         185       195  validate

# %%
final_val = pd.DataFrame()

# %%
sorted(val['label'].unique())
# Out:
# ['abseiling',
#  'air drumming',
#  'answering questions',
#  'applauding',
#  'applying cream',
#  'archery',
#  'arm wrestling',
#  'arranging flowers',
#  'assembling computer',
#  'auctioning',
#  'baby waking up',
#  'baking cookies',
#  'balloon blowing',
#  'bandaging',
#  'barbequing',
#  'bartending',
#  'beatboxing',
#  'bee keeping',
#  'belly dancing',
#  'bench pressing',
#  'bending back',
#  'bending metal',
#  'biking through snow',
#  'blasting sand',
#  'blowing glass',
#  'blowing leaves',
#  'blowing nose',
#  'blowing out candles',
#  'bobsledding',
#  'bookbinding',
#  'bouncing on trampoline',
#  'bowling',
#  'braiding hair',
#  'breading or breadcrumbing',
#  'breakdancing',
#  'brush painting',
#  'brushing hair',
#  'brushing teeth',
#  'building cabinet',
#  'building shed',
#  'bungee jumping',
#  'busking',
#  'canoeing or kayaking',
#  'capoeira',
#  'carrying baby',
#  'cartwheeling',
#  'carving pumpkin',
#  'catching fish',
# ...

# %%
len(sorted(train['label'].unique()))
# Out:
# 400

# %%
 l = ['walking up',
'preparing salad',
'inflating balloons',
'pillow fight',
'vacuuming floor']

# %%
val_list = list(final_train['label'].unique())

# %%
len(val_list)
# Out:
# 45

# %%
val_list
# Out:
# ['paragliding',
#  'catching or throwing baseball',
#  'dancing macarena',
#  'laughing',
#  'eating cake',
#  'beatboxing',
#  'feeding birds',
#  'opening present',
#  'swinging on something',
#  'making pizza',
#  'kitesurfing',
#  'ice climbing',
#  'slacklining',
#  'chopping wood',
#  'cartwheeling',
#  'archery',
#  'welding',
#  'roller skating',
#  'playing flute',
#  'deadlifting',
#  'bouncing on trampoline',
#  'shoveling snow',
#  'playing keyboard',
#  'celebrating',
#  'high jump',
#  'capoeira',
#  'finger snapping',
#  'side kick',
#  'brushing hair',
#  'cooking sausages',
#  'throwing ball',
#  'hammer throw',
#  'dribbling basketball',
#  'stretching leg',
#  'breakdancing',
#  'snowmobiling',
#  'canoeing or kayaking',
#  'headbanging',
#  'exercising with an exercise ball',
#  'blowing out candles',
#  'watering plants',
#  'cheerleading',
#  'milking cow',
#  'snowboarding',
#  'driving car']

# %%
for i in val_list:
    if i in sorted(val['label'].unique()):
        print(i)
    else:
        print('No')
# Out:
# paragliding
# catching or throwing baseball
# dancing macarena
# laughing
# eating cake
# beatboxing
# feeding birds
# opening present
# swinging on something
# making pizza
# kitesurfing
# ice climbing
# slacklining
# chopping wood
# cartwheeling
# archery
# welding
# roller skating
# playing flute
# deadlifting
# bouncing on trampoline
# shoveling snow
# playing keyboard
# celebrating
# high jump
# capoeira
# finger snapping
# side kick
# brushing hair
# cooking sausages
# throwing ball
# hammer throw
# dribbling basketball
# stretching leg
# breakdancing
# snowmobiling
# canoeing or kayaking
# headbanging
# exercising with an exercise ball
# blowing out candles
# watering plants
# cheerleading
# milking cow
# snowboarding
# driving car

# %%
for i in val_list:
    print(len(val[val['label'] == i ].head(15)))
# Out:
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 45

# %%
for i in val_list:
    final_val = final_val.append(val[val['label'] == i ].head(15))

# %%
final_val.shape
# Out:
# (675, 5)

# %%
len(final_val['label'].unique())
# Out:
# 45

# %%
final_val.to_csv("Validation.csv")

# %%
final_train.shape , final_val.shape
# Out:
# ((675, 5), (675, 5))
